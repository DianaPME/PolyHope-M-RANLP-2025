# %%
import pandas as pd
import openai
import json
from pydantic import BaseModel, Field

# %% [markdown]
# ## Reading dataset

# %%
file_path= 'dataset_merged_ranlp.csv'
df= pd.read_csv(file_path)
# Filter by train dataset
train_df = df[df['source'] == 'train']

# %% [markdown]
# ## Binary Classification

# %% [markdown]
# ## Extracting random samples

# %%
# Number of examples per class
num_samples = 3 

# Get random examples from train for each combination of binary 
few_shot_examples = train_df.groupby(['binary']).apply(
    lambda x: x.sample(n=min(num_samples, len(x)), random_state=42)
)

# Reset index to avoid multi-index issues
few_shot_examples = few_shot_examples.reset_index(drop=True)
# Out:
# C:\Users\dianm\AppData\Local\Temp\ipykernel_9364\3926961786.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   few_shot_examples = train_df.groupby(['binary']).apply(

# %%
few_shot_examples.to_csv('binary_few_shot_examples.csv')

# %% [markdown]
# ## Binary Samples for english

# %%
# Filter for english
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'english')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['binary']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1:  perhaps i felt that way after checking my #btc wallet but was encouraged and hopeful with puss do yourself favor and good by buying some puss a community driven gemstonewhere every member is a priority #pussdao #puss #bnb web  Label 1: Hope Text 2: according to dhruv rathee  arrests should depend on the follower count of the person filing the fir  to think there are enough idiots out there who listen to his dumb youtube videos as the gospel truth what a joke this is  Label 2: Not Hope'

# %% [markdown]
# ## Binary Samples for spanish

# %%
# Filter for spanish
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'spanish')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['binary']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1: hoy desperte y ya no te extraño ahora solo siento un sentimiento de emocion y esperanza para ser la mejor version de mi que pueda existir hearthandslightskintone Label 1: Hope'

# %% [markdown]
# ## Binary Samples for german

# %%
# Filter for german
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'german')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['binary']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1:  positiv sicher aber sind älter und niemals modernisieworden müssten erst an die anderen zugesagten a4 angepasst werden Label 1: Not Hope Text 2:  jaja man erinnesich wie deutschland in den 1940ern frieden nach ganz europa gebracht hat mit immer mehr und schwereren waffen glauben diese trottel ihren schwachsinn eigentlich selbst? Label 2: Not Hope'

# %% [markdown]
# ## Binary Samples for urdu

# %%
# Filter for urdu
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'urdu')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['binary']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1:  انشا اللہبہت جلد ان شہدا کا بدلہ لیں گے Label 1: Hope'

# %% [markdown]
# ## Multiclass Classification

# %% [markdown]
# ## Extracting random samples

# %%
 # Number of examples per class
num_samples = 3 

# Get random examples from train for each combination of binary and language
few_shot_examples = train_df.groupby(['multiclass','language']).apply(
    lambda x: x.sample(n=min(num_samples, len(x)), random_state=42)
)

# Reset index to avoid multi-index issues
few_shot_examples = few_shot_examples.reset_index(drop=True)

few_shot_examples
# Out:
# C:\Users\dianm\AppData\Local\Temp\ipykernel_9364\4115702204.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   few_shot_examples = train_df.groupby(['multiclass','language']).apply(
#                                                  text    binary  \
# 0   #ForbiddenDoor thoughts so far today:\n\nThe p...      Hope
# 1   #USER# I’m currently matching/exceeding expect...      Hope
# 2   #USER# Spokane is losing a good one! Appreciat...      Hope
# 3   #USER# Nun ja, die Hoffnung besteht. Bei den m...      Hope
# 4        #USER# Gute Nacht, J. und schöne Träume! ✨💚✨      Hope
# 5   Wow, Futures tatsächlich ins Close positiv.\nM...      Hope
# 6   me ven normal pero todos los días pienso en lo...      Hope
# 7   #USER# Viendo a varios de los que tengo alrede...      Hope
# 8   Disfruten mucho el tiempo de calidad que les b...      Hope
# 9   جیسے علماء سودی نظام کیخلاف اکھٹے ہوئے ہیں کاش...      Hope
# 10  #USER# #USER# #USER# #USER# #USER# #USER# #USE...      Hope
# 11  RT #USER# مجھے بیٹھنے کی جگہ ملے، میری آرزو کا...      Hope
# 12  LMAOOOO I pray no one has to go through this😂 ...  Not Hope
# 13  Could he be the warg he was and maintain his p...  Not Hope
# 14  Chongyun, you have to believe me... It wasn't ...  Not Hope
# 15  #USER# #USER# Viele der Aufklärer und ihrer Na...  Not Hope
# 16  RT #USER# Wunsch und Wirklichkeit bleiben in m...  Not Hope
# 17  #USER# #USER# Hat da einer noch Hoffnung auf "...  Not Hope
# 18  #USER# #USER# #USER# Sabes que eso fue en 2012...  Not Hope
# 19  Hoy es de esos días en los que anhelo y necesi...  Not Hope
# 20  #USER# La de la clase de falo? jajaja y si cre...  Not Hope
# 21  حکم کس کا بھی تھا ساتھ کون کھڑا رہا اس وقت یہ ...  Not Hope
# 22  ایک قصبے میں رہنے والے عجیب لوگ ان کی زندگی کے...  Not Hope
# 23  #USER# جہاں اللہ نے واحد کا صیغہ استعمال کیا  ...  Not Hope
# 24  20 years ago people used to aspire to own thei...      Hope
# 25  I hope I can find a person who shares the same...      Hope
# 26  #USER# #USER# Blue dot in red TX but I’m hopef...      Hope
# 27  Mmmh Fluglärm - welch lieblicher Klang. \nIst ...      Hope
# 28  #USER# Hier, in der 🇨🇭realisieren wir unsere b...      Hope
# 29  #USER# #USER# Wir werden eine grüne Bürgermeis...      Hope
# 30  RT #USER# Este video me da esperanza, al menos...      Hope
# 31  ÁNGELUS | A las 12:00h te invitamos a rezar el...      Hope
# 32  RT #USER# #USER# Estoy deseando verla, porque ...      Hope
# 33  میں نے اپنے نفس کا اچھے سے محاسبہ کیا ہے۔ مجھے...      Hope
# 34  خواب پورا ہو گیا مجھے اور #USER# کو آخرکار خان...      Hope
# 35  اللہ کا لاکھ احسان ہے اُس نے ہمیں “کل کیا ہوگا...      Hope
# 36  i wish skz had like official like continuous d...      Hope
# 37  Asian tigers were making the sinking country e...      Hope
# 38  #USER# #USER# #USER# #USER# Yes pray it doesn’...      Hope
# 39  #USER# #USER# Kansas wird deine Träume zerstör...      Hope
# 40  #USER# Hat er nicht mal selbst in einem Video ...      Hope
# 41  #USER# Ich könnte mir eine Senseo mit Milchdin...      Hope
# 42  #USER# La luz se ha ido y todo está triste,  L...      Hope
# 43  #USER# #USER# #USER# Bien buena que está ojalá...      Hope
# 44              acá con 3 horas d sueño m voy a morir      Hope
# 45  #USER# بہت اچھا یہ ہی خبیث باجوہ اور اس کے جیس...      Hope
# 46  انسان پہ ایسا وقت بھی آتا ہے جب اسکی سب سے بڑی...      Hope
# 47  پچھلے 6 سال حاجی کی مٹھائی کا آسرا، اگلے 3 سال...      Hope
#
#           multiclass source  \
# 0   Generalized Hope  train
# 1   Generalized Hope  train
# 2   Generalized Hope  train
# 3   Generalized Hope  train
# 4   Generalized Hope  train
# 5   Generalized Hope  train
# 6   Generalized Hope  train
# 7   Generalized Hope  train
# 8   Generalized Hope  train
# 9   Generalized Hope  train
# 10  Generalized Hope  train
# 11  Generalized Hope  train
# 12          Not Hope  train
# 13          Not Hope  train
# 14          Not Hope  train
# 15          Not Hope  train
# 16          Not Hope  train
# 17          Not Hope  train
# 18          Not Hope  train
# 19          Not Hope  train
# 20          Not Hope  train
# 21          Not Hope  train
# 22          Not Hope  train
# 23          Not Hope  train
# 24    Realistic Hope  train
# 25    Realistic Hope  train
# 26    Realistic Hope  train
# 27    Realistic Hope  train
# 28    Realistic Hope  train
# 29    Realistic Hope  train
# 30    Realistic Hope  train
# 31    Realistic Hope  train
# 32    Realistic Hope  train
# 33    Realistic Hope  train
# 34    Realistic Hope  train
# 35    Realistic Hope  train
# 36  Unrealistic Hope  train
# 37  Unrealistic Hope  train
# 38  Unrealistic Hope  train
# 39  Unrealistic Hope  train
# 40  Unrealistic Hope  train
# 41  Unrealistic Hope  train
# 42  Unrealistic Hope  train
# 43  Unrealistic Hope  train
# 44  Unrealistic Hope  train
# 45  Unrealistic Hope  train
# 46  Unrealistic Hope  train
# 47  Unrealistic Hope  train
#
#                                            clean_text language
# 0   #forbiddendoor thoughts so far today the pop f...  english
# 1    im currently matchingexceeding expectations a...  english
# 2    spokane is losing a good one! appreciate all ...  english
# 3         nun ja die hoffnung besteht bei den meisten   german
# 4    gute nacht j und schöne träume! sparklesgreen...   german
# 5   wow futures tatsächlich ins close positiv mal ...   german
# 6   me ven normal pero todos los dias pienso en lo...  spanish
# 7    viendo a varios de los que tengo alrededor cr...  spanish
# 8   disfruten mucho el tiempo de calidad que les b...  spanish
# 9   جیسے علماء سودی نظام کیخلاف اکھٹے ہوے ہیں کاش ...     urdu
# 10   الفاظ نہیں ہیں اس درد کو لکھنے کے لیے loudlyc...     urdu
# 11   مجھے بیٹھنے کی جگہ ملے میری رزو کا بھرم رہےتی...     urdu
# 12  lmaoooo i pray no one has to go through thisfa...  english
# 13  could he be the warg he was and maintain his p...  english
# 14  chongyun you have to believe me it wasnt me wh...  english
# 15   viele der aufklärer und ihrer nachfahren im 1...   german
# 16   wunsch und wirklichkeit bleiben in meinem leb...   german
# 17   hat da einer noch hoffnung auf vom tellerwäsc...   german
# 18   sabes que eso fue en 2012 no? ese año el balo...  spanish
# 19  hoy es de esos dias en los que anhelo y necesi...  spanish
# 20   la de la clase de falo? jajaja y si creo que ...  spanish
# 21  حکم کس کا بھی تھا ساتھ کون کھڑا رہا اس وقت یہ ...     urdu
# 22  ایک قصبے میں رہنے والے عجیب لوگ ان کی زندگی کے...     urdu
# 23   جہاں اللہ نے واحد کا صیغہ استعمال کیا وہ اپنی...     urdu
# 24  20 years ago people used to aspire to own thei...  english
# 25  i hope i can find a person who shares the same...  english
# 26   blue dot in red tx but im hopeful for a blue ...  english
# 27  mmmh fluglärm  welch lieblicher klang ist mir ...   german
# 28   hier in der witzerlandrealisieren wir unsere ...   german
# 29   wir werden eine grüne bürgermeisterin haben s...   german
# 30   este video me da esperanza al menos ya tengo ...  spanish
# 31  angelus  a las 1200h te invitamos a rezar el a...  spanish
# 32   estoy deseando verla porque no querre yo conv...  spanish
# 33  میں نے اپنے نفس کا اچھے سے محاسبہ کیا ہے مجھے ...     urdu
# 34  خواب پورا ہو گیا مجھے اور کو خرکار خان صاحب کا...     urdu
# 35  اللہ کا لاکھ احسان ہے اس نے ہمیں کل کیا ہوگا ک...     urdu
# 36  i wish skz had like official like continuous d...  english
# 37  asian tigers were making the sinking country e...  english
# 38   yes pray it doesnt say what kind of prayer so...  english
# 39              kansas wird deine träume zerstören lo   german
# 40   hat er nicht mal selbst in einem video oder d...   german
# 41   ich könnte mir eine senseo mit milchdingsi vo...   german
# 42   la luz se ha ido y todo esta triste la soleda...  spanish
# 43   bien buena que esta ojala la supiera hacer fa...  spanish
# 44              aca con 3 horas d sueño m voy a morir  spanish
# 45   بہت اچھا یہ ہی خبیث باجوہ اور اس کے جیسے حرام...     urdu
# 46  انسان پہ ایسا وقت بھی تا ہے جب اسکی سب سے بڑی ...     urdu
# 47  پچھلے  سال حاجی کی مٹھای کا سرا اگلے  سال حافظ...     urdu

# %%
few_shot_examples.to_csv('multiclass_few_shot_examples.csv')

# %% [markdown]
# ## Multiclass Samples for english

# %%
# Filter for english
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'english')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['multiclass']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1: #forbiddendoor thoughts so far today the pop for suzukis kazi ni nare entrancehim and eddie squaring offamp just the chaos of that match in general was sick and then the triple threat tag was amazing as well ftr finally being so over is beautiful and i really hope dax is ok Label 1: Generalized Hope Text 2:  im currently matchingexceeding expectations and in line with the club vision so im hoping ill be okay always a risk though Label 2: Generalized Hope Text 3:  spokane is losing a good one! appreciate all of your hard work youve earned this and i hope you enjoy the new position! Label 3: Generalized Hope Text 4: lmaoooo i pray no one has to go through thisfacewithtearsofjoy fck them other kids tho  Label 4: Not Hope Text 5: could he be the warg he was and maintain his place within the demon lords army? or was a chance meeting with a strange woman who desired to become a caladrius for a druid king meant to ruin him? megaphone  Label 5: Not Hope Text 6: chongyun you have to believe me it wasnt me who laid traps inside the house what? its not haunted? well i uh couldnt have known that could i? Label 6: Not Hope Text 7: 20 years ago people used to aspire to own their own homethese days they just want the foodbank to be stocked and find a nhs dentist Label 7: Realistic Hope Text 8: i hope i can find a person who shares the same music type with me clownface Label 8: Realistic Hope Text 9:  blue dot in red tx but im hopeful for a blue november #betofortexas Label 9: Realistic Hope Text 10: i wish skz had like official like continuous designs on their merch idk i feel like its all a bit random facewithspiraleyes Label 10: Unrealistic Hope Text 11: asian tigers were making the sinking country even earlier still inshallah will make #pmlnrebuildingpakistan #na133 wahabshahzad3  Label 11: Unrealistic Hope Text 12:  yes pray it doesnt say what kind of prayer so i the pagan can pray to my gods in class the satanist can do their prayer and the muslim do their prayer yes its a wonderful win Label 12: Unrealistic Hope'

# %% [markdown]
# ## Multiclass Samples for spanish

# %%
# Filter for spanish
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'spanish')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['multiclass']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1: me ven normal pero todos los dias pienso en los futuros turnos de bomberos que voy a hacer y rezo para no cagarme toda Label 1: Generalized Hope Text 2:  viendo a varios de los que tengo alrededor creo que ese episodio dio demasiadas ideas pero son felices Label 2: Generalized Hope Text 3: disfruten mucho el tiempo de calidad que les brindan sus novios es lo que mas anhelo con el mio se que todo esfuerzo que hacemos tendra su recompensa crossedfingerslightskintonemendingheart Label 3: Generalized Hope Text 4:  sabes que eso fue en 2012 no? ese año el balon de oro se lo regalan a cristiano Label 4: Not Hope Text 5: hoy es de esos dias en los que anhelo y necesito comer fruta Label 5: Not Hope Text 6:  la de la clase de falo? jajaja y si creo que no soporto nailpolishlightskintone Label 6: Not Hope Text 7:  este video me da esperanza al menos ya tengo la cara de artesania oaxaqueña smilingfacewithtear  Label 7: Realistic Hope Text 8: angelus  a las 1200h te invitamos a rezar el angelus poniendo ante nuestra madre tus intenciones en este segundo sabado de cuaresma pedimos por la congregacion de las hijas de jesus para que nuestra purisima madre del buen camino las proteja  Label 8: Realistic Hope Text 9:  estoy deseando verla porque no querre yo convertirme algun dia en reina de las walkirias Label 9: Realistic Hope Text 10:  la luz se ha ido y todo esta triste la soledad nos abraza sin resistencia y es en estos dias grises que me pregunto como puedo volver a encontrar la alegria? ahora miro hacia el cielo y rezo para que en este dia gris se vaya el llanto backhandindexpointingdownlightskintonebackhandindexpointingdownlightskintonebackhandindexpointingdownlightskintone Label 10: Unrealistic Hope Text 11:  bien buena que esta ojala la supiera hacer facesavoringfood Label 11: Unrealistic Hope Text 12: aca con 3 horas d sueño m voy a morir Label 12: Unrealistic Hope'

# %% [markdown]
# ## Multiclass Samples for german

# %%
# Filter for german
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'german')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['multiclass']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1:  nun ja die hoffnung besteht bei den meisten Label 1: Generalized Hope Text 2:  gute nacht j und schöne träume! sparklesgreenheartsparkles Label 2: Generalized Hope Text 3: wow futures tatsächlich ins close positiv mal sehen was gleich tsla bringt  Label 3: Generalized Hope Text 4:  viele der aufklärer und ihrer nachfahren im 19 jahrhundewaren tatsächlich kinder ihrer zeit das heißt nicht dass sie in ihrem wunsch verblendet waren ob die zeit nach 1871 bis heute so eine größere erfolgsgeschichte war als die periode des hrr darf angezweifelt werden Label 4: Not Hope Text 5:  wunsch und wirklichkeit bleiben in meinem leben auch eher zwei dinge die kaum vereinbar sind Label 5: Not Hope Text 6:  hat da einer noch hoffnung auf vom tellerwäscher zum milliardär ? oder bist du es elon? facewithtearsofjoy Label 6: Not Hope Text 7: mmmh fluglärm  welch lieblicher klang ist mir 2 orte weiter nie wirklich so stark aufgefallen disguisedface aber vielleicht träume ich dann von urlaub?  Label 7: Realistic Hope Text 8:  hier in der witzerlandrealisieren wir unsere berufliche träume die angenehme nebenwirkung davon ist man kann dabei etwas gutes auf die beine stellen das allenden schweizern u den ausländern dient ich bin froh hier leben zu dürfen Label 8: Realistic Hope Text 9:  wir werden eine grüne bürgermeisterin haben sie sind am ziel ihrer träumewoozyface  Label 9: Realistic Hope Text 10:  kansas wird deine träume zerstören lo Label 10: Unrealistic Hope Text 11:  hat er nicht mal selbst in einem video oder discordleak gesagt dass er absichtlich so verbal eskaliedamit die nachbar mitbekommen wie oft und dolle er gestalkt wird in der hoffnung die mal rufen bei der pinea an? Label 11: Unrealistic Hope Text 12:  ich könnte mir eine senseo mit milchdingsi vorstellen? thinkingface Label 12: Unrealistic Hope'

# %% [markdown]
# ## Multiclass Samples for urdu

# %%
# Filter for urdu
filtered_examples = few_shot_examples[
    (few_shot_examples['language'] == 'urdu')
]

# Convert filtered examples to the desired format
few_shot_text = " ".join([
    f"Text {i}: {row['clean_text']} Label {i}: {row['multiclass']}"
    for i, (_, row) in enumerate(filtered_examples.iterrows(), 1)
])

few_shot_text
# Out:
# 'Text 1: جیسے علماء سودی نظام کیخلاف اکھٹے ہوے ہیں کاش کہ سود کی حرمت کے بارے مطلع کرنے والے صحابہ کرام کے دفاع کیلے بھی اکھٹے ہوجاے brokenheart Label 1: Generalized Hope Text 2:  الفاظ نہیں ہیں اس درد کو لکھنے کے لیے loudlycryingfacepensiveface پ تو ماں باپ ہیں ہم ان معصوم بچوں کا دکھ ج تک نہیں بھول سکے اللہ پاک پ کو صبر عطا کرے اور سب بچوں کو جنت میں اعلی مقام عطا فرماے مین palmsuptogether Label 2: Generalized Hope Text 3:  مجھے بیٹھنے کی جگہ ملے میری رزو کا بھرم رہےتیری انجمن میں اگر نہیں تیری انجمن سے قریں سہیپیر سید نصیرالدین نصیر رح Label 3: Generalized Hope Text 4: حکم کس کا بھی تھا ساتھ کون کھڑا رہا اس وقت یہ بات زیادہ معنی رکھتیاسد عمر نے وہی کیا جو پی ٹی ا کا منشور تھا روز اول سے بعد میں بھی وہی کیا جب دوبارہ منسٹری ملی نہ وہ کسی کے گے جھکے نہ رکےاللہ جس سے جو کام لینا چاہےasadumar stay strong u will always be my favorite smilingfacewithsmilingeyes Label 4: Not Hope Text 5: ایک قصبے میں رہنے والے عجیب لوگ ان کی زندگی کے بارے میں جانا licker کی ہے سب کچھ licks ہے جو ایک دمی ایک جسم ہے کہ وہ اس کے ساتھ رہنے کے لے گھر لیتا ہے جو پتہ چلا ہے کہ ایک dumpster غوطہ ایک گڑیا کے ساتھ ایک پاگل لڑکی کو اس طرح کپڑے پہنے اپنی بری راہوں کی صفای پیش لڑکیوں کے لے چاہتا ہے جو ایک لڑکے  ف بیٹ انتہای میں سیاہ اور سفید فلم میں اس شاٹ رنگ سے باہر کے ساتھ بہتر ہے مونوکروم گھر فلم احساس سے اٹھ دو قدم دور کنارے لگتے ہیں ایک troma فلم کی طرح اس فلم کے فٹ بیٹھتا ہے اور شروع میں مزہ لیکن weirds خاطر زیادہ تر اس کے عجیب ہے اور جلد ہی ایک اجلاس ہونے کے تناظر بور سے ایک کے بعد سے پ سیٹ اپ پ اندازہ اس کی ایک بہت always وقت نہیں جا رہا ہے جہاں کی قسم سکتے دیکھنے بن جاتا ہے لیکن اس کے لے کافی مزہ نہیں ہو حالانکہ میں صفای تے ہوے نہیں دیکھا ورتھ ورنہ پ نے کچھ بھی نہیں دیکھنے کے لے اگر ایک شاٹ اور اپنی گولڈن لڑکیوں کی اگلی سیٹ netflix سے نے کے لے انتظار کر رہے ہیں Label 5: Not Hope Text 6:  جہاں اللہ نے واحد کا صیغہ استعمال کیا وہ اپنی زات کے لےجیسے مجھ سے ڈرو میں انعام دوں گا  رزق میں دیتا ہوں وغیرہ وغیرہجہاں جمع کا صیغہ ہوگا وہاںاللہ اپنے قوانین کو شامل کرتا ہےجیسے نکاح کی بات ہوی نکاح جو ہے قانون ہےاسی طرح اللہ فرماتا ہےجیسے ہم ہدایت دیں ہم  Label 6: Not Hope Text 7: میں نے اپنے نفس کا اچھے سے محاسبہ کیا ہے مجھے اپنے اندر کوی کام کی بات نہیں ملی سواے ایک کےکہ میں رحمن کی ذات سے رحمت کے امید رکھتا ہوں #allahuakbar  Label 7: Realistic Hope Text 8: خواب پورا ہو گیا مجھے اور کو خرکار خان صاحب کا دستخط شدہ مفلر اور کتاب مل گsmilingfacewithhearteyesredheartfire اللہ نے چاہا تو بہت جلد خان صاحب سے ملاقات بھی ہو جاے گیredheartبہت بہت شکریہ اس انمول گفٹ کے لے  Label 8: Realistic Hope Text 9: اللہ کا لاکھ احسان ہے اس نے ہمیں کل کیا ہوگا کی خبر سے محض اس لیے لاعلم رکھا کہ ہماری کل ایک خوبصورت دن ہوگا کی امید قام رہےfoldedhandsroseredheartrosehundredpointsakistan Label 9: Realistic Hope Text 10:  بہت اچھا یہ ہی خبیث باجوہ اور اس کے جیسے حرامیوں سے ڈرز لیتے ہیں اور اپنے ہی شہریوں کو گمنام کر کے مارتے ہیں اللہ ان سب خبیثوں کو جہنم نصیب کرے Label 10: Unrealistic Hope Text 11: انسان پہ ایسا وقت بھی تا ہے جب اسکی سب سے بڑی خواہش صرف یہ ہوتی ہے کہ کاش اسکی محسوس کرنے کی حس نہ ہوwiltedflowerpurpleheart Label 11: Unrealistic Hope Text 12: پچھلے  سال حاجی کی مٹھای کا سرا اگلے  سال حافظ کے حلوہ کی تمنا  سال سے سمان سے نازل شدہ کڑیل خوبرو گبرو لیڈرز کے لالی پاپس سے امیدیں اس دوران میں دبلے پتلے بھوکے ننگے بنگالی جن کو مارشل ریس بوجھ سمجھتی رہی کہاں سے کہاں نکل گے! Label 12: Unrealistic Hope'
