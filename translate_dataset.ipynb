# %%
# !pip install pandas deep-translator

# %%
# !pip install transformers torch pandas

# %%
import pandas as pd

# Load the CSV file
file_path = '/content/es_train.csv'  # Replace with your file path
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                                                 text binary        multiclass
# 0  🎬Outer Banks🎬 (temporada 3) la verdad que teni...   Hope  Generalized Hope
# 1  -Después del poco éxito en el grupo de la Jet ...   Hope  Generalized Hope
# 2  Bárbara López yo te rezo y te hago un monument...   Hope  Generalized Hope
# 3  RT #USER# #USER# #USER# Ojalá nos ayuden a des...   Hope    Realistic Hope
# 4  #USER# No tengo las palabras justas. Pero rezo...   Hope    Realistic Hope

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  11243.000000
# mean    5621.000000
# std     3245.718873
# min        0.000000
# 25%     2810.500000
# 50%     5621.000000
# 75%     8431.500000
# max    11242.000000

# %%
import pandas as pd
import torch
from transformers import MarianMTModel, MarianTokenizer

# Load model for Spanish → Urdu
model_name = 'Helsinki-NLP/opus-mt-en-ur'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Load your file
df = pd.read_csv('en_train.csv')

# Translation function
def translate_es_to_ur(text):
    inputs = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt").to(device)
    translated = model.generate(**inputs)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

# Apply translation
df['text_ur'] = df['text'].apply(translate_es_to_ur)

# Save output
df.to_csv('en_to_ur_train.csv', index=False)

# %%
import pandas as pd
import torch
from transformers import MarianMTModel, MarianTokenizer

# Load Spanish to English model
model_name = 'Helsinki-NLP/opus-mt-es-en'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Load your file
df = pd.read_csv('/content/es_train.csv')

# Translation function
def translate(text):
    inputs = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt").to(device)
    translated = model.generate(**inputs)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

# Translate all rows
df['text_en'] = df['text'].apply(translate)

# Save the translated file
df.to_csv('es_to_en_train.csv', index=False)
